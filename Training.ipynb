# %%
# !sudo apt -y install libportaudio2
# !pip install -q tflite-model-maker
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   libportaudio2
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 65.4 kB of archives.
# After this operation, 223 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportaudio2 amd64 19.6.0-1build1 [65.4 kB]
# Fetched 65.4 kB in 1s (120 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 122349 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1build1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1build1) ...
# Setting up libportaudio2:amd64 (19.6.0-1build1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 47.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.8/203.8 kB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.6/240.6 kB 28.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 12.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 71.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 55.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 98.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 65.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 110.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 46.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 92.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.3/222.3 kB 27.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 98.4 MB/s eta 0:00:00
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# statsmodels 0.13.5 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# plotnine 0.10.1 requires matplotlib>=3.5.0, but you have matplotlib 3.4.3 which is incompatible.
# mizani 0.8.1 requires matplotlib>=3.5.0, but you have matplotlib 3.4.3 which is incompatible.

# %%
import os

import numpy as np

import tensorflow as tf
assert tf.__version__.startswith('2')

from tflite_model_maker import model_spec
from tflite_model_maker import image_classifier
from tflite_model_maker.config import ExportFormat
from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.image_classifier import DataLoader

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_path = "/content/drive/MyDrive/Data"

# %%
data = DataLoader.from_folder(image_path)

# %%
train_data, rest_data = data.split(0.8)
validation_data, test_data = rest_data.split(0.5)

# %%
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(data.gen_dataset().unbatch().take(25)):
  plt.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)
  plt.xlabel(data.index_to_label[label.numpy()])
plt.show()

# %%
model = image_classifier.create(train_data, model_spec=model_spec.get('mobilenet_v2'), validation_data=validation_data,epochs=50,use_augmentation=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hub_keras_layer_v1v2 (HubKe  (None, 1280)             2257984
#  rasLayerV1V2)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None
# Epoch 1/50
# 13/13 [==============================] - 65s 5s/step - loss: 0.9178 - accuracy: 0.6442 - val_loss: 0.4100 - val_accuracy: 0.9434
# Epoch 2/50
# 13/13 [==============================] - 4s 292ms/step - loss: 0.5975 - accuracy: 0.8510 - val_loss: 0.4309 - val_accuracy: 0.9623
# Epoch 3/50
# 13/13 [==============================] - 5s 393ms/step - loss: 0.5455 - accuracy: 0.9159 - val_loss: 0.4176 - val_accuracy: 0.9811
# Epoch 4/50
# 13/13 [==============================] - 6s 447ms/step - loss: 0.5120 - accuracy: 0.9183 - val_loss: 0.3902 - val_accuracy: 0.9811
# Epoch 5/50
# 13/13 [==============================] - 4s 287ms/step - loss: 0.4810 - accuracy: 0.9014 - val_loss: 0.3775 - val_accuracy: 0.9811
# Epoch 6/50
# 13/13 [==============================] - 4s 280ms/step - loss: 0.4566 - accuracy: 0.9255 - val_loss: 0.3598 - val_accuracy: 1.0000
# Epoch 7/50
# 13/13 [==============================] - 5s 430ms/step - loss: 0.4398 - accuracy: 0.9399 - val_loss: 0.3594 - val_accuracy: 0.9811
# Epoch 8/50
# 13/13 [==============================] - 5s 415ms/step - loss: 0.4552 - accuracy: 0.9327 - val_loss: 0.3769 - val_accuracy: 1.0000
# Epoch 9/50
# 13/13 [==============================] - 4s 281ms/step - loss: 0.4151 - accuracy: 0.9423 - val_loss: 0.3666 - val_accuracy: 0.9811
# Epoch 10/50
# 13/13 [==============================] - 6s 461ms/step - loss: 0.4642 - accuracy: 0.9183 - val_loss: 0.3594 - val_accuracy: 0.9811
# Epoch 11/50
# 13/13 [==============================] - 4s 279ms/step - loss: 0.4370 - accuracy: 0.9423 - val_loss: 0.3707 - val_accuracy: 0.9811
# Epoch 12/50
# 13/13 [==============================] - 3s 265ms/step - loss: 0.4234 - accuracy: 0.9543 - val_loss: 0.3798 - val_accuracy: 0.9811
# Epoch 13/50
# 13/13 [==============================] - 5s 396ms/step - loss: 0.4371 - accuracy: 0.9471 - val_loss: 0.3817 - val_accuracy: 0.9811
# Epoch 14/50
# 13/13 [==============================] - 5s 398ms/step - loss: 0.4380 - accuracy: 0.9519 - val_loss: 0.3650 - val_accuracy: 0.9811
# Epoch 15/50
# 13/13 [==============================] - 3s 267ms/step - loss: 0.4655 - accuracy: 0.9207 - val_loss: 0.3577 - val_accuracy: 1.0000
# Epoch 16/50
# 13/13 [==============================] - 3s 267ms/step - loss: 0.4355 - accuracy: 0.9351 - val_loss: 0.3540 - val_accuracy: 1.0000
# Epoch 17/50
# 13/13 [==============================] - 5s 426ms/step - loss: 0.4300 - accuracy: 0.9519 - val_loss: 0.3566 - val_accuracy: 0.9811
# Epoch 18/50
# 13/13 [==============================] - 5s 374ms/step - loss: 0.4348 - accuracy: 0.9351 - val_loss: 0.3556 - val_accuracy: 0.9811
# Epoch 19/50
# 13/13 [==============================] - 3s 268ms/step - loss: 0.4035 - accuracy: 0.9591 - val_loss: 0.3587 - val_accuracy: 1.0000
# Epoch 20/50
# 13/13 [==============================] - 3s 264ms/step - loss: 0.4184 - accuracy: 0.9519 - val_loss: 0.3625 - val_accuracy: 1.0000
# Epoch 21/50
# 13/13 [==============================] - 5s 426ms/step - loss: 0.3928 - accuracy: 0.9615 - val_loss: 0.3479 - val_accuracy: 0.9811
# Epoch 22/50
# 13/13 [==============================] - 3s 266ms/step - loss: 0.3999 - accuracy: 0.9519 - val_loss: 0.3509 - val_accuracy: 1.0000
# Epoch 23/50
# 13/13 [==============================] - 3s 266ms/step - loss: 0.3881 - accuracy: 0.9663 - val_loss: 0.3570 - val_accuracy: 0.9811
# Epoch 24/50
# 13/13 [==============================] - 5s 366ms/step - loss: 0.4215 - accuracy: 0.9495 - val_loss: 0.3511 - val_accuracy: 0.9811
# Epoch 25/50
# 13/13 [==============================] - 5s 404ms/step - loss: 0.4068 - accuracy: 0.9543 - val_loss: 0.3530 - val_accuracy: 0.9811
# Epoch 26/50
# 13/13 [==============================] - 3s 269ms/step - loss: 0.3913 - accuracy: 0.9712 - val_loss: 0.3581 - val_accuracy: 0.9811
# Epoch 27/50
# 13/13 [==============================] - 3s 269ms/step - loss: 0.4201 - accuracy: 0.9471 - val_loss: 0.3612 - val_accuracy: 0.9811
# Epoch 28/50
# 13/13 [==============================] - 5s 406ms/step - loss: 0.4335 - accuracy: 0.9375 - val_loss: 0.3641 - val_accuracy: 0.9811
# Epoch 29/50
# 13/13 [==============================] - 5s 387ms/step - loss: 0.4011 - accuracy: 0.9688 - val_loss: 0.4130 - val_accuracy: 0.9623
# Epoch 30/50
# 13/13 [==============================] - 3s 269ms/step - loss: 0.4380 - accuracy: 0.9303 - val_loss: 0.3702 - val_accuracy: 0.9811
# Epoch 31/50
# 13/13 [==============================] - 3s 268ms/step - loss: 0.4280 - accuracy: 0.9495 - val_loss: 0.3632 - val_accuracy: 0.9811
# Epoch 32/50
# 13/13 [==============================] - 5s 426ms/step - loss: 0.4108 - accuracy: 0.9495 - val_loss: 0.3608 - val_accuracy: 1.0000
# Epoch 33/50
# 13/13 [==============================] - 3s 268ms/step - loss: 0.4463 - accuracy: 0.9303 - val_loss: 0.3700 - val_accuracy: 1.0000
# Epoch 34/50
# 13/13 [==============================] - 4s 316ms/step - loss: 0.4079 - accuracy: 0.9615 - val_loss: 0.3541 - val_accuracy: 1.0000
# Epoch 35/50
# 13/13 [==============================] - 5s 419ms/step - loss: 0.4062 - accuracy: 0.9543 - val_loss: 0.3546 - val_accuracy: 0.9811
# Epoch 36/50
# 13/13 [==============================] - 3s 266ms/step - loss: 0.3970 - accuracy: 0.9688 - val_loss: 0.3578 - val_accuracy: 0.9811
# Epoch 37/50
# 13/13 [==============================] - 6s 447ms/step - loss: 0.4051 - accuracy: 0.9543 - val_loss: 0.3678 - val_accuracy: 0.9811
# Epoch 38/50
# 13/13 [==============================] - 4s 322ms/step - loss: 0.4208 - accuracy: 0.9423 - val_loss: 0.3629 - val_accuracy: 0.9811
# Epoch 39/50
# 13/13 [==============================] - 3s 270ms/step - loss: 0.3874 - accuracy: 0.9760 - val_loss: 0.3697 - val_accuracy: 0.9811
# Epoch 40/50
# 13/13 [==============================] - 3s 261ms/step - loss: 0.4000 - accuracy: 0.9591 - val_loss: 0.3635 - val_accuracy: 0.9811
# Epoch 41/50
# 13/13 [==============================] - 5s 435ms/step - loss: 0.3979 - accuracy: 0.9567 - val_loss: 0.3686 - val_accuracy: 0.9811
# Epoch 42/50
# 13/13 [==============================] - 3s 265ms/step - loss: 0.3878 - accuracy: 0.9639 - val_loss: 0.3669 - val_accuracy: 0.9811
# Epoch 43/50
# 13/13 [==============================] - 3s 274ms/step - loss: 0.3935 - accuracy: 0.9615 - val_loss: 0.3605 - val_accuracy: 0.9811
# Epoch 44/50
# 13/13 [==============================] - 5s 439ms/step - loss: 0.4071 - accuracy: 0.9567 - val_loss: 0.3533 - val_accuracy: 0.9811
# Epoch 45/50
# 13/13 [==============================] - 3s 263ms/step - loss: 0.3763 - accuracy: 0.9736 - val_loss: 0.3624 - val_accuracy: 0.9811
# Epoch 46/50
# 13/13 [==============================] - 4s 307ms/step - loss: 0.3766 - accuracy: 0.9736 - val_loss: 0.3523 - val_accuracy: 0.9811
# Epoch 47/50
# 13/13 [==============================] - 6s 486ms/step - loss: 0.3947 - accuracy: 0.9543 - val_loss: 0.3501 - val_accuracy: 0.9811
# Epoch 48/50
# 13/13 [==============================] - 4s 273ms/step - loss: 0.3952 - accuracy: 0.9567 - val_loss: 0.3501 - val_accuracy: 0.9811
# Epoch 49/50
# 13/13 [==============================] - 3s 273ms/step - loss: 0.3985 - accuracy: 0.9543 - val_loss: 0.3533 - val_accuracy: 0.9811
# Epoch 50/50
# 13/13 [==============================] - 6s 452ms/step - loss: 0.3799 - accuracy: 0.9736 - val_loss: 0.3528 - val_accuracy: 0.9811

# %% [markdown]
# Have a look at the detailed model structure.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hub_keras_layer_v1v2 (HubKe  (None, 1280)             2257984
#  rasLayerV1V2)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 3)                 3843
#
# =================================================================
# Total params: 2,261,827
# Trainable params: 3,843
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
loss, accuracy = model.evaluate(test_data)
# Out:
# 2/2 [==============================] - 8s 3s/step - loss: 0.3635 - accuracy: 0.9623

# %%
# A helper function that returns 'red'/'black' depending on if its two input
# parameter matches or not.
def get_label_color(val1, val2):
  if val1 == val2:
    return 'black'
  else:
    return 'red'

# Then plot 100 test images and their predicted labels.
# If a prediction result is different from the label provided label in "test"
# dataset, we will highlight it in red color.
plt.figure(figsize=(20, 20))
predicts = model.predict_top_k(test_data)
for i, (image, label) in enumerate(test_data.gen_dataset().unbatch().take(100)):
  ax = plt.subplot(10, 10, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(image.numpy(), cmap=plt.cm.gray)

  predict_label = predicts[i][0][0]
  color = get_label_color(predict_label,
                          test_data.index_to_label[label.numpy()])
  ax.xaxis.label.set_color(color)
  plt.xlabel('Predicted: %s' % predict_label)
plt.show()

# %%
model.export(export_dir='.')
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "

# %%
model.evaluate_tflite('model.tflite', test_data)
# Out:
# {'accuracy': 0.9622641509433962}
